# %%
import random 
import math 
import time 
from tqdm import tqdm 

from collections import defaultdict

# %% [markdown]
# # 通用函数定义

# %%
# 定义装饰器，监控运行时间
def timmer(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        res = func(*args, **kwargs)
        stop_time = time.time()
        print("Func {:s}, run time: {:f}".format(func.__name__, stop_time-start_time))
        return res 
    return wrapper

# %% [markdown]
# # 数据处理相关函数

# %%
class Dataset:
    def __init__(self, fp):
        self.data = self.loadData(fp)
    
    @timmer
    def loadData(self, fp):
        data = [f.strip().split('\t')[:3] for f in open(fp, 'r').readlines()[1:]]
        return data 
    
    @timmer
    def splitData(self, M, k, seed=2019):
        train, test = [], []
        random.seed(seed)
        
        for user, item, tag in self.data: 
            if random.randint(0, M-1) == k:
                test.append((user, item, tag))
            else:
                train.append((user, item, tag))
        # 转换成字典形式, user->set(items)
        def convert_dict(data):
            data_dict = {}
            for user, item, tag in data: 
                if user not in data_dict:
                    data_dict[user] = {}
                if item not in data_dict[user]:
                    data_dict[user][item] = set()
                data_dict[user][item].add(tag)
            for user in data_dict:
                for item in data_dict[user]:
                    data_dict[user][item] = list(data_dict[user][item])
            return data_dict
        
        return convert_dict(train), convert_dict(test)

# %% [markdown]
# # 评价指标

# %%
class Metric:
    def __init__(self, train, test, GetRecommendation):
        self.train = train
        self.test = test
        self.GetRecommendation = GetRecommendation
        self.recs = self.getRec()
        
    # 为test中的每个用户进行推荐
    def getRec(self):
        recs = {}
        for user in self.test:
            recs[user] = {}
            for item in self.test[user]:
                rank = self.GetRecommendation(user, item)
                recs[user][item] = rank
        return recs
    
    # 定义精确率的指标
    def precision(self):
        all, hit = 0, 0 
        for user in self.test:
            for item in self.test[user]:
                test_tags = set(self.test[user][item])
                rank = self.recs[user][item]
                for tag, score in rank:
                    if tag  in test_tags:
                        hit += 1 
                all += len(rank)
        return round(hit/all*100, 2)
    
    # 定义召回率指标计算方式
    def recall(self):
        all, hit = 0, 0 
        for user in self.test: 
            for item in self.test[user]:
                test_tags = set(self.test[user][item])
                rank = self.recs[user][item]
                for tag, score in rank: 
                    if tag in test_tags:
                        hit += 1 
                all += len(test_tags)
        return round(hit / all * 100, 2)
    
    def eval(self):
        metric = {"Precision": self.precision(), 
                 "Recall": self.recall()}
        
        print("Metric: ", metric)
        return metric

# %% [markdown]
# # 算法实现
#
# - Popular
# - UserPopular
# - ItemPopular
# - HybirdPopular

# %%
# 热门标签
def Popular(train, N):
    tags = {}
    for user in train:
        for item in train[user]:
            for tag in train[user][item]:
                tags[tag] = tags.get(tag, 0) + 1 
    
    tags = list(sorted(tags.items(), key=lambda x: x[1], reverse=True))[:N]
    
    def GetRecommendation(user, item):
        return tags
    
    return GetRecommendation

# %%
# 推荐用户最热门的标签
def UserPopular(train, N):
    user_tags = {}
    for user in train: 
        user_tags[user] = {}
        for item in train[user]:
            for tag in train[user][item]:
                user_tags[user][tag] = user_tags[user].get(tag, 0) + 1 
    
    user_tags = {k: list(sorted(v.items(), key=lambda x: x[1], reverse=True)) for k, v in user_tags.items()}
    
    def GetRecommendation(user, item):
        if user in user_tags:
            return user_tags[user][:N]
        else:
            get = Popular(train, N)
            return get(user, item)
        
    return GetRecommendation

# %%
# 推荐物品最热门标签
def ItemPopular(train, N):
    # 统计Item_tags
    item_tags = {}
    for user in train: 
        for item in train[user]:
            if item not in item_tags:
                item_tags[item] = {}
            for tag in train[user][item]:
                item_tags[item][tag] = item_tags[item].get(tag, 0) + 1 
    item_tags = {k: list(sorted(v.items(), key=lambda x: x[1], reverse=True)) for k, v in item_tags.items()}
    
    def GetRecommendation(user, item):
        if item in item_tags:
            return item_tags[item][:N]
        else:
            get = Popular(train, N)
            return get(user, item)
    
    return GetRecommendation

# %%
# 联合用户和商品热门推荐
def HybridPopular(train, N, alpha):
    # 统计user_tags
    user_tags = {}
    for user in train:
        user_tags[user] = {}
        for item in train[user]:
            for tag in train[user][item]:
                user_tags[user][tag] = user_tags[user].get(tag, 0) + 1 
    
    # 统计item_tags
    item_tags = {}
    for user in train:
        for item in train[user]:
            if item not in item_tags:
                item_tags[item] = {}
                for tag in train[user][item]:
                    item_tags[item][tag] = item_tags[item].get(item, 0) + 1 
    
    def GetRecommendation(user, item):
        tag_score = {}
        if user in user_tags:
            max_user_tag = max(user_tags[user].values())
            for tag in user_tags[user]:
                if tag not in tag_score:
                    tag_score[tag] = 0 
                tag_score[tag] += (1-alpha) * user_tags[user][tag] / max_user_tag
        
        if item in item_tags:
            max_item_tag = max(item_tags[item].values())
            for tag in item_tags[item]:
                if tag not in tag_score:
                    tag_score[tag] = 0 
                tag_score[tag] += alpha * item_tags[item][tag] / max_item_tag
        return list(sorted(tag_score.items(), key=lambda x: x[1], reverse=True))[:N]
    
    return GetRecommendation

# %% [markdown]
# # 实验

# %%
class Experiment:
    def __init__(self, M, N, fp="data/hetrec2011-delicious-2k/user_taggedbookmarks.dat", rt="Popular"):
        self.M = M
        self.N = N
        self.fp = fp 
        self.rt = rt
        self.alg = {"Popular": Popular, "UserPopular": UserPopular,
                   "ItemPopular": ItemPopular, "HybridPopular": HybridPopular}
        
        
    #定义单次实验
    @timmer
    def worker(self, train, test, **kwargs):
        getRecommendation = self.alg[self.rt](train, self.N, **kwargs)
        metric = Metric(train, test, getRecommendation)
        return metric.eval()
    
    # 定义多次实验
    @timmer
    def run(self, **kwargs):
        metrics = {"Precision": 0, "Recall": 0}
        dataset = Dataset(self.fp)
        for ii in range(self.M):
            train, test = dataset.splitData(self.M, ii)
            print(f"Experiment: {ii}")
            metric = self.worker(train, test, **kwargs)
            metrics = {k: metrics[k]+metric[k] for k in metrics}
        
        metrics = {k: metrics[k] / self.M for k in metrics}
        print("Average Result (M={}, N={}): {}".format(self.M, self.N, metrics))

# %% [markdown]
# ## Popular实验

# %%
M, N = 10, 10 
exp = Experiment(M, N, rt="Popular")
exp.run()
# Out:
# Func loadData, run time: 0.471173
# Func splitData, run time: 0.718057
# Experiment: 0
# Metric:  {'Precision': 0.82, 'Recall': 6.37}
# Func worker, run time: 0.127186
# Func splitData, run time: 0.542508
# Experiment: 1
# Metric:  {'Precision': 0.85, 'Recall': 6.67}
# Func worker, run time: 0.248760
# Func splitData, run time: 0.555226
# Experiment: 2
# Metric:  {'Precision': 0.82, 'Recall': 6.4}
# Func worker, run time: 0.117698
# Func splitData, run time: 0.706522
# Experiment: 3
# Metric:  {'Precision': 0.86, 'Recall': 6.76}
# Func worker, run time: 0.116232
# Func splitData, run time: 0.697612
# Experiment: 4
# Metric:  {'Precision': 0.83, 'Recall': 6.46}
# Func worker, run time: 0.119412
# Func splitData, run time: 0.546528
# Experiment: 5
# Metric:  {'Precision': 0.86, 'Recall': 6.73}
# Func worker, run time: 0.123459
# Func splitData, run time: 0.690699
# Experiment: 6
# Metric:  {'Precision': 0.85, 'Recall': 6.65}
# Func worker, run time: 0.118489
# Func splitData, run time: 0.700311
# Experiment: 7
# Metric:  {'Precision': 0.86, 'Recall': 6.74}
# Func worker, run time: 0.114789
# Func splitData, run time: 0.703569
# Experiment: 8
# Metric:  {'Precision': 0.84, 'Recall': 6.59}
# Func worker, run time: 0.115965
# Func splitData, run time: 0.538703
# Experiment: 9
# Metric:  {'Precision': 0.85, 'Recall': 6.69}
# Func worker, run time: 0.114906
# Average Result (M=10, N=10): {'Precision': 0.844, 'Recall': 6.606}
# Func run, run time: 8.320230

# %% [markdown]
# ## UserPopular实验

# %%
exp = Experiment(M, N, rt="UserPopular")
exp.run()
# Out:
# Func loadData, run time: 0.446649
# Func splitData, run time: 0.729339
# Experiment: 0
# Metric:  {'Precision': 3.14, 'Recall': 24.41}
# Func worker, run time: 0.179784
# Func splitData, run time: 0.772570
# Experiment: 1
# Metric:  {'Precision': 3.2, 'Recall': 24.95}
# Func worker, run time: 0.318386
# Func splitData, run time: 0.803341
# Experiment: 2
# Metric:  {'Precision': 3.15, 'Recall': 24.53}
# Func worker, run time: 0.242467
# Func splitData, run time: 0.549572
# Experiment: 3
# Metric:  {'Precision': 3.17, 'Recall': 24.73}
# Func worker, run time: 0.525570
# Func splitData, run time: 0.548713
# Experiment: 4
# Metric:  {'Precision': 3.13, 'Recall': 24.38}
# Func worker, run time: 0.589575
# Func splitData, run time: 0.532585
# Experiment: 5
# Metric:  {'Precision': 3.23, 'Recall': 25.22}
# Func worker, run time: 0.168817
# Func splitData, run time: 0.678190
# Experiment: 6
# Metric:  {'Precision': 3.17, 'Recall': 24.64}
# Func worker, run time: 0.230900
# Func splitData, run time: 0.705462
# Experiment: 7
# Metric:  {'Precision': 3.18, 'Recall': 24.78}
# Func worker, run time: 0.245776
# Func splitData, run time: 0.571083
# Experiment: 8
# Metric:  {'Precision': 3.17, 'Recall': 24.61}
# Func worker, run time: 0.908157
# Func splitData, run time: 0.641115
# Experiment: 9
# Metric:  {'Precision': 3.17, 'Recall': 24.75}
# Func worker, run time: 0.459717
# Average Result (M=10, N=10): {'Precision': 3.1710000000000003, 'Recall': 24.7}
# Func run, run time: 11.018634

# %% [markdown]
# ## ItemPopular

# %%
exp = Experiment(M, N, rt="ItemPopular")
exp.run()
# Out:
# Func loadData, run time: 0.351101
# Func splitData, run time: 0.692680
# Experiment: 0
# Metric:  {'Precision': 1.58, 'Recall': 7.98}
# Func worker, run time: 55.226680
# Func splitData, run time: 0.539450
# Experiment: 1
# Metric:  {'Precision': 1.59, 'Recall': 8.05}
# Func worker, run time: 57.113130
# Func splitData, run time: 0.698452
# Experiment: 2
# Metric:  {'Precision': 1.58, 'Recall': 8.0}
# Func worker, run time: 59.773259
# Func splitData, run time: 0.708363
# Experiment: 3
# Metric:  {'Precision': 1.58, 'Recall': 8.02}
# Func worker, run time: 55.266559
# Func splitData, run time: 0.710807
# Experiment: 4
# Metric:  {'Precision': 1.59, 'Recall': 8.02}
# Func worker, run time: 50.985781
# Func splitData, run time: 0.694144
# Experiment: 5
# Metric:  {'Precision': 1.59, 'Recall': 8.1}
# Func worker, run time: 52.782524
# Func splitData, run time: 0.702360
# Experiment: 6
# Metric:  {'Precision': 1.58, 'Recall': 7.97}
# Func worker, run time: 49.121496
# Func splitData, run time: 0.698344
# Experiment: 7
# Metric:  {'Precision': 1.58, 'Recall': 8.02}
# Func worker, run time: 51.625380
# Func splitData, run time: 0.683536
# Experiment: 8
# Metric:  {'Precision': 1.61, 'Recall': 8.14}
# Func worker, run time: 49.077482
# Func splitData, run time: 0.684002
# Experiment: 9
# Metric:  {'Precision': 1.55, 'Recall': 7.87}
# Func worker, run time: 51.289927
# Average Result (M=10, N=10): {'Precision': 1.583, 'Recall': 8.017}
# Func run, run time: 539.562211

# %% [markdown]
# ## HybridPopular

# %%
for alpha in range(0, 11):
    alpha /= 10 
    print("alpha = ", alpha)
    exp = Experiment(M, N, rt="HybridPopular")
    exp.run(alpha=alpha)
# Out:
# alpha =  0.0
# Func loadData, run time: 0.463718
# Func splitData, run time: 0.720193
# Experiment: 0
# Metric:  {'Precision': 3.13, 'Recall': 24.41}
# Func worker, run time: 2.046175
# Func splitData, run time: 0.684545
# Experiment: 1
# Metric:  {'Precision': 3.2, 'Recall': 24.97}
# Func worker, run time: 2.016257
# Func splitData, run time: 0.698015
# Experiment: 2
# Metric:  {'Precision': 3.15, 'Recall': 24.53}
# Func worker, run time: 1.996331
# Func splitData, run time: 0.528147
# Experiment: 3
# Metric:  {'Precision': 3.16, 'Recall': 24.73}
# Func worker, run time: 2.175389
# Func splitData, run time: 0.532241
# Experiment: 4
# Metric:  {'Precision': 3.13, 'Recall': 24.39}
# Func worker, run time: 2.194852
# Func splitData, run time: 0.527457
# Experiment: 5
# Metric:  {'Precision': 3.23, 'Recall': 25.22}
# Func worker, run time: 2.018466
# Func splitData, run time: 0.670770
# Experiment: 6
# Metric:  {'Precision': 3.16, 'Recall': 24.65}
# Func worker, run time: 2.035819
# Func splitData, run time: 0.689310
# Experiment: 7
# Metric:  {'Precision': 3.18, 'Recall': 24.78}
# Func worker, run time: 2.061975
# Func splitData, run time: 0.687291
# Experiment: 8
# Metric:  {'Precision': 3.16, 'Recall': 24.62}
# Func worker, run time: 2.024099
# Func splitData, run time: 0.540696
# Experiment: 9
# Metric:  {'Precision': 3.16, 'Recall': 24.76}
# Func worker, run time: 2.186321
# Average Result (M=10, N=10): {'Precision': 3.166, 'Recall': 24.706}
# Func run, run time: 27.628201
# alpha =  0.1
# Func loadData, run time: 0.342611
# Func splitData, run time: 0.716420
# Experiment: 0
# Metric:  {'Precision': 3.11, 'Recall': 24.22}
# Func worker, run time: 2.089878
# Func splitData, run time: 0.706390
# Experiment: 1
# Metric:  {'Precision': 3.17, 'Recall': 24.78}
# Func worker, run time: 2.115095
# Func splitData, run time: 0.549565
# Experiment: 2
# Metric:  {'Precision': 3.13, 'Recall': 24.39}
# Func worker, run time: 2.176106
# Func splitData, run time: 0.540095
# Experiment: 3
# Metric:  {'Precision': 3.15, 'Recall': 24.61}
# Func worker, run time: 2.097081
# Func splitData, run time: 0.691536
# Experiment: 4
# Metric:  {'Precision': 3.1, 'Recall': 24.17}
# Func worker, run time: 2.072179
# Func splitData, run time: 0.676336
# Experiment: 5
# Metric:  {'Precision': 3.21, 'Recall': 25.05}
# Func worker, run time: 2.058120
# Func splitData, run time: 0.682946
# Experiment: 6
# Metric:  {'Precision': 3.14, 'Recall': 24.42}
# Func worker, run time: 2.094760
# Func splitData, run time: 0.535411
# Experiment: 7
# Metric:  {'Precision': 3.15, 'Recall': 24.54}
# Func worker, run time: 2.260535
# Func splitData, run time: 0.542836
# Experiment: 8
# Metric:  {'Precision': 3.14, 'Recall': 24.44}
# Func worker, run time: 2.232641
# Func splitData, run time: 0.540334
# Experiment: 9
# Metric:  {'Precision': 3.13, 'Recall': 24.5}
# Func worker, run time: 2.072797
# Average Result (M=10, N=10): {'Precision': 3.143, 'Recall': 24.511999999999997}
# Func run, run time: 27.925119
# alpha =  0.2
# Func loadData, run time: 0.436708
# Func splitData, run time: 0.712172
# Experiment: 0
# Metric:  {'Precision': 3.04, 'Recall': 23.72}
# Func worker, run time: 2.111473
# Func splitData, run time: 0.697598
# Experiment: 1
# Metric:  {'Precision': 3.12, 'Recall': 24.33}
# Func worker, run time: 2.125309
# Func splitData, run time: 0.704159
# Experiment: 2
# Metric:  {'Precision': 3.07, 'Recall': 23.89}
# Func worker, run time: 2.071350
# Func splitData, run time: 0.536991
# Experiment: 3
# Metric:  {'Precision': 3.11, 'Recall': 24.27}
# Func worker, run time: 2.241447
# Func splitData, run time: 0.543832
# Experiment: 4
# Metric:  {'Precision': 3.03, 'Recall': 23.6}
# Func worker, run time: 2.234819
# Func splitData, run time: 0.539162
# Experiment: 5
# Metric:  {'Precision': 3.15, 'Recall': 24.63}
# Func worker, run time: 2.090033
# Func splitData, run time: 0.684059
# Experiment: 6
# Metric:  {'Precision': 3.07, 'Recall': 23.9}
# Func worker, run time: 2.342016
# Func splitData, run time: 0.803417
# Experiment: 7
# Metric:  {'Precision': 3.08, 'Recall': 24.02}
# Func worker, run time: 2.503479
# Func splitData, run time: 0.765647
# Experiment: 8
# Metric:  {'Precision': 3.07, 'Recall': 23.92}
# Func worker, run time: 2.344133
# Func splitData, run time: 0.576588
# Experiment: 9
# Metric:  {'Precision': 3.06, 'Recall': 23.96}
# Func worker, run time: 2.400723
# Average Result (M=10, N=10): {'Precision': 3.08, 'Recall': 24.024000000000004}
# Func run, run time: 29.596484
# alpha =  0.3
# Func loadData, run time: 0.358321
# Func splitData, run time: 0.783803
# Experiment: 0
# Metric:  {'Precision': 2.99, 'Recall': 23.27}
# Func worker, run time: 2.221183
# Func splitData, run time: 0.755061
# Experiment: 1
# Metric:  {'Precision': 3.04, 'Recall': 23.75}
# Func worker, run time: 2.282506
# Func splitData, run time: 0.581139
# Experiment: 2
# Metric:  {'Precision': 3.01, 'Recall': 23.48}
# Func worker, run time: 2.344644
# Func splitData, run time: 0.568336
# Experiment: 3
# Metric:  {'Precision': 3.02, 'Recall': 23.58}
# Func worker, run time: 2.133211
# Func splitData, run time: 0.691668
# Experiment: 4
# Metric:  {'Precision': 2.95, 'Recall': 23.03}
# Func worker, run time: 2.099280
# Func splitData, run time: 0.696732
# Experiment: 5
# Metric:  {'Precision': 3.08, 'Recall': 24.08}
# Func worker, run time: 2.102880
# Func splitData, run time: 0.714052
# Experiment: 6
# Metric:  {'Precision': 2.99, 'Recall': 23.26}
# Func worker, run time: 2.119678
# Func splitData, run time: 0.568310
# Experiment: 7
# Metric:  {'Precision': 3.01, 'Recall': 23.5}
# Func worker, run time: 2.437157
# Func splitData, run time: 0.628388
# Experiment: 8
# Metric:  {'Precision': 3.0, 'Recall': 23.37}
# Func worker, run time: 2.645111
# Func splitData, run time: 0.643125
# Experiment: 9
# Metric:  {'Precision': 2.99, 'Recall': 23.39}
# Func worker, run time: 2.379820
# Average Result (M=10, N=10): {'Precision': 3.008, 'Recall': 23.470999999999997}
# Func run, run time: 29.887116
# alpha =  0.4
# Func loadData, run time: 0.467923
# Func splitData, run time: 0.790095
# Experiment: 0
# Metric:  {'Precision': 2.93, 'Recall': 22.83}
# Func worker, run time: 2.172525
# Func splitData, run time: 0.729625
# Experiment: 1
# Metric:  {'Precision': 2.99, 'Recall': 23.35}
# Func worker, run time: 2.213115
# Func splitData, run time: 0.723498
# Experiment: 2
# Metric:  {'Precision': 2.94, 'Recall': 22.9}
# Func worker, run time: 2.099344
# Func splitData, run time: 0.705594
# Experiment: 3
# Metric:  {'Precision': 2.96, 'Recall': 23.14}
# Func worker, run time: 2.177515
# Func splitData, run time: 0.566223
# Experiment: 4
# Metric:  {'Precision': 2.88, 'Recall': 22.5}
# Func worker, run time: 2.373609
# Func splitData, run time: 0.548404
# Experiment: 5
# Metric:  {'Precision': 3.01, 'Recall': 23.51}
# Func worker, run time: 2.294277
# Func splitData, run time: 0.543403
# Experiment: 6
# Metric:  {'Precision': 2.91, 'Recall': 22.7}
# Func worker, run time: 2.439512
# Func splitData, run time: 0.676930
# Experiment: 7
# Metric:  {'Precision': 2.95, 'Recall': 22.98}
# Func worker, run time: 2.121342
# Func splitData, run time: 0.700553
# Experiment: 8
# Metric:  {'Precision': 2.93, 'Recall': 22.83}
# Func worker, run time: 2.074852
# Func splitData, run time: 0.689473
# Experiment: 9
# Metric:  {'Precision': 2.93, 'Recall': 22.89}
# Func worker, run time: 2.044709
# Average Result (M=10, N=10): {'Precision': 2.943, 'Recall': 22.962999999999994}
# Func run, run time: 29.283196
# alpha =  0.5
# Func loadData, run time: 0.336913
# Func splitData, run time: 0.740230
# Experiment: 0
# Metric:  {'Precision': 2.88, 'Recall': 22.45}
# Func worker, run time: 2.095663
# Func splitData, run time: 0.699587
# Experiment: 1
# Metric:  {'Precision': 2.94, 'Recall': 22.93}
# Func worker, run time: 2.131885
# Func splitData, run time: 0.566788
# Experiment: 2
# Metric:  {'Precision': 2.89, 'Recall': 22.49}
# Func worker, run time: 2.277605
# Func splitData, run time: 0.554789
# Experiment: 3
# Metric:  {'Precision': 2.9, 'Recall': 22.68}
# Func worker, run time: 2.293976
# Func splitData, run time: 0.557944
# Experiment: 4
# Metric:  {'Precision': 2.82, 'Recall': 21.99}
# Func worker, run time: 2.152898
# Func splitData, run time: 0.691974
# Experiment: 5
# Metric:  {'Precision': 2.96, 'Recall': 23.13}
# Func worker, run time: 2.174805
# Func splitData, run time: 0.701659
# Experiment: 6
# Metric:  {'Precision': 2.86, 'Recall': 22.28}
# Func worker, run time: 2.086979
# Func splitData, run time: 0.740057
# Experiment: 7
# Metric:  {'Precision': 2.89, 'Recall': 22.52}
# Func worker, run time: 2.130090
# Func splitData, run time: 0.550553
# Experiment: 8
# Metric:  {'Precision': 2.88, 'Recall': 22.4}
# Func worker, run time: 2.258133
# Func splitData, run time: 0.533791
# Experiment: 9
# Metric:  {'Precision': 2.86, 'Recall': 22.41}
# Func worker, run time: 2.285165
# Average Result (M=10, N=10): {'Precision': 2.888, 'Recall': 22.528}
# Func run, run time: 28.693351
# alpha =  0.6
# Func loadData, run time: 0.347186
# Func splitData, run time: 0.741132
# Experiment: 0
# Metric:  {'Precision': 2.87, 'Recall': 22.4}
# Func worker, run time: 2.085892
# Func splitData, run time: 0.689652
# Experiment: 1
# Metric:  {'Precision': 2.93, 'Recall': 22.9}
# Func worker, run time: 2.100322
# Func splitData, run time: 0.554241
# Experiment: 2
# Metric:  {'Precision': 2.88, 'Recall': 22.44}
# Func worker, run time: 2.274111
# Func splitData, run time: 0.560003
# Experiment: 3
# Metric:  {'Precision': 2.9, 'Recall': 22.65}
# Func worker, run time: 2.290517
# Func splitData, run time: 0.745495
# Experiment: 4
# Metric:  {'Precision': 2.81, 'Recall': 21.94}
# Func worker, run time: 2.219900
# Func splitData, run time: 0.712132
# Experiment: 5
# Metric:  {'Precision': 2.95, 'Recall': 23.07}
# Func worker, run time: 2.126129
# Func splitData, run time: 0.703874
# Experiment: 6
# Metric:  {'Precision': 2.85, 'Recall': 22.23}
# Func worker, run time: 2.129067
# Func splitData, run time: 0.552761
# Experiment: 7
# Metric:  {'Precision': 2.88, 'Recall': 22.48}
# Func worker, run time: 2.186958
# Func splitData, run time: 0.542328
# Experiment: 8
# Metric:  {'Precision': 2.87, 'Recall': 22.35}
# Func worker, run time: 2.275931
# Func splitData, run time: 0.531936
# Experiment: 9
# Metric:  {'Precision': 2.85, 'Recall': 22.34}
# Func worker, run time: 2.078101
# Average Result (M=10, N=10): {'Precision': 2.8790000000000004, 'Recall': 22.479999999999997}
# Func run, run time: 28.579039
# alpha =  0.7
# Func loadData, run time: 0.443895
# Func splitData, run time: 0.721508
# Experiment: 0
# Metric:  {'Precision': 2.87, 'Recall': 22.4}
# Func worker, run time: 2.064646
# Func splitData, run time: 0.698109
# Experiment: 1
# Metric:  {'Precision': 2.93, 'Recall': 22.9}
# Func worker, run time: 2.122699
# Func splitData, run time: 0.706343
# Experiment: 2
# Metric:  {'Precision': 2.88, 'Recall': 22.44}
# Func worker, run time: 2.074661
# Func splitData, run time: 0.720988
# Experiment: 3
# Metric:  {'Precision': 2.9, 'Recall': 22.65}
# Func worker, run time: 2.259663
# Func splitData, run time: 0.566269
# Experiment: 4
# Metric:  {'Precision': 2.81, 'Recall': 21.94}
# Func worker, run time: 2.276319
# Func splitData, run time: 0.549094
# Experiment: 5
# Metric:  {'Precision': 2.95, 'Recall': 23.07}
# Func worker, run time: 2.286230
# Func splitData, run time: 0.561571
# Experiment: 6
# Metric:  {'Precision': 2.85, 'Recall': 22.23}
# Func worker, run time: 2.221147
# Func splitData, run time: 0.690789
# Experiment: 7
# Metric:  {'Precision': 2.88, 'Recall': 22.48}
# Func worker, run time: 2.111258
# Func splitData, run time: 0.714448
# Experiment: 8
# Metric:  {'Precision': 2.87, 'Recall': 22.35}
# Func worker, run time: 2.112890
# Func splitData, run time: 0.688051
# Experiment: 9
# Metric:  {'Precision': 2.85, 'Recall': 22.34}
# Func worker, run time: 2.042536
# Average Result (M=10, N=10): {'Precision': 2.8790000000000004, 'Recall': 22.479999999999997}
# Func run, run time: 28.764616
# alpha =  0.8
# Func loadData, run time: 0.334209
# Func splitData, run time: 0.756286
# Experiment: 0
# Metric:  {'Precision': 2.87, 'Recall': 22.4}
# Func worker, run time: 2.120092
# Func splitData, run time: 0.718968
# Experiment: 1
# Metric:  {'Precision': 2.93, 'Recall': 22.9}
# Func worker, run time: 2.093956
# Func splitData, run time: 0.537268
# Experiment: 2
# Metric:  {'Precision': 2.88, 'Recall': 22.44}
# Func worker, run time: 2.212310
# Func splitData, run time: 0.564522
# Experiment: 3
# Metric:  {'Precision': 2.9, 'Recall': 22.65}
# Func worker, run time: 2.307375
# Func splitData, run time: 0.540856
# Experiment: 4
# Metric:  {'Precision': 2.81, 'Recall': 21.94}
# Func worker, run time: 2.086872
# Func splitData, run time: 0.686181
# Experiment: 5
# Metric:  {'Precision': 2.95, 'Recall': 23.07}
# Func worker, run time: 2.087025
# Func splitData, run time: 0.699876
# Experiment: 6
# Metric:  {'Precision': 2.85, 'Recall': 22.23}
# Func worker, run time: 2.107316
# Func splitData, run time: 0.695945
# Experiment: 7
# Metric:  {'Precision': 2.88, 'Recall': 22.48}
# Func worker, run time: 2.085654
# Func splitData, run time: 0.533353
# Experiment: 8
# Metric:  {'Precision': 2.87, 'Recall': 22.35}
# Func worker, run time: 2.220328
# Func splitData, run time: 0.531177
# Experiment: 9
# Metric:  {'Precision': 2.85, 'Recall': 22.34}
# Func worker, run time: 2.236666
# Average Result (M=10, N=10): {'Precision': 2.8790000000000004, 'Recall': 22.479999999999997}
# Func run, run time: 28.288158
# alpha =  0.9
# Func loadData, run time: 0.353016
# Func splitData, run time: 0.715651
# Experiment: 0
# Metric:  {'Precision': 2.87, 'Recall': 22.4}
# Func worker, run time: 2.094622
# Func splitData, run time: 0.696301
# Experiment: 1
# Metric:  {'Precision': 2.93, 'Recall': 22.9}
# Func worker, run time: 2.086981
# Func splitData, run time: 0.534303
# Experiment: 2
# Metric:  {'Precision': 2.88, 'Recall': 22.44}
# Func worker, run time: 2.214679
# Func splitData, run time: 0.538147
# Experiment: 3
# Metric:  {'Precision': 2.9, 'Recall': 22.65}
# Func worker, run time: 2.113365
# Func splitData, run time: 0.686512
# Experiment: 4
# Metric:  {'Precision': 2.81, 'Recall': 21.94}
# Func worker, run time: 2.061811
# Func splitData, run time: 0.685212
# Experiment: 5
# Metric:  {'Precision': 2.95, 'Recall': 23.07}
# Func worker, run time: 2.128655
# Func splitData, run time: 0.707387
# Experiment: 6
# Metric:  {'Precision': 2.85, 'Recall': 22.23}
# Func worker, run time: 2.129498
# Func splitData, run time: 0.705384
# Experiment: 7
# Metric:  {'Precision': 2.88, 'Recall': 22.48}
# Func worker, run time: 2.105509
# Func splitData, run time: 0.532861
# Experiment: 8
# Metric:  {'Precision': 2.87, 'Recall': 22.35}
# Func worker, run time: 2.209899
# Func splitData, run time: 0.547951
# Experiment: 9
# Metric:  {'Precision': 2.85, 'Recall': 22.34}
# Func worker, run time: 2.257129
# Average Result (M=10, N=10): {'Precision': 2.8790000000000004, 'Recall': 22.479999999999997}
# Func run, run time: 28.241077
# alpha =  1.0
# Func loadData, run time: 0.365464
# Func splitData, run time: 0.717695
# Experiment: 0
# Metric:  {'Precision': 1.62, 'Recall': 12.63}
# Func worker, run time: 2.001594
# Func splitData, run time: 0.688358
# Experiment: 1
# Metric:  {'Precision': 1.65, 'Recall': 12.85}
# Func worker, run time: 1.965593
# Func splitData, run time: 0.536977
# Experiment: 2
# Metric:  {'Precision': 1.61, 'Recall': 12.53}
# Func worker, run time: 2.112498
# Func splitData, run time: 0.538890
# Experiment: 3
# Metric:  {'Precision': 1.63, 'Recall': 12.73}
# Func worker, run time: 1.970636
# Func splitData, run time: 0.677404
# Experiment: 4
# Metric:  {'Precision': 1.59, 'Recall': 12.39}
# Func worker, run time: 1.964960
# Func splitData, run time: 0.696686
# Experiment: 5
# Metric:  {'Precision': 1.63, 'Recall': 12.76}
# Func worker, run time: 2.235332
# Func splitData, run time: 0.708629
# Experiment: 6
# Metric:  {'Precision': 1.58, 'Recall': 12.27}
# Func worker, run time: 1.992748
# Func splitData, run time: 0.698491
# Experiment: 7
# Metric:  {'Precision': 1.62, 'Recall': 12.61}
# Func worker, run time: 2.000756
# Func splitData, run time: 0.551451
# Experiment: 8
# Metric:  {'Precision': 1.59, 'Recall': 12.39}
# Func worker, run time: 2.128964
# Func splitData, run time: 0.532037
# Experiment: 9
# Metric:  {'Precision': 1.62, 'Recall': 12.68}
# Func worker, run time: 2.133134
# Average Result (M=10, N=10): {'Precision': 1.614, 'Recall': 12.584}
# Func run, run time: 27.351373
